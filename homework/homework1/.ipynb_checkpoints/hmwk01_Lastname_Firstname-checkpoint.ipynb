# %% [markdown]
# # Homework 1: Data Cleaning and Exploratory Data Analysis
# ***
#
# **Name**: Matthew Sredojevic
#
# ***
#
# This assignment is due on Moodle by **5pm on Friday February 2nd**. Your solutions to theoretical questions should be done in Markdown directly below the associated question.  Your solutions to computational questions should include any specified Python code and results as well as written commentary on your conclusions.  Remember that you are encouraged to discuss the problems with your classmates, but **you must write all code and solutions on your own**.
#
# **NOTES**:
#
# - Unless a url is given for a data set, you will find the required data in the same directory as this assignment on GitHub.
# - If you're not familiar with typesetting math directly into Markdown then by all means, do your work on paper first and then typeset it later.  Remember that there is a [reference guide](https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference) linked on Piazza on writing math in Markdown.
# - It is **bad form** to make your reader interpret numerical output from your code.  If a question asks you to compute some value from the data you should show your code output **AND** write a summary of the results in Markdown directly below your code.

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# ### Problem 1
# ***
#
# An owner of an animal sanctuary wants to estimate her sanctuary's average food consumption over the next year in order to estimate the future food costs. Her sanctuary comprises 75 pandas, 25 otters, 50 buffalo, and 50 owls. The owner pops open her SanctuaryTrackr App's Current Resident List, randomly selects 24 animals from it, and tracks their food consumptions in pounds per day (lbs/day) over the next week. So as to get a good estimate, she intentionally selects 9 pandas, 3 otters, 6 buffalo, and 6 owls.
#
# Identify the following:
#
# - the population
# - the sample frame
# - the sample
# - the type of sample
# - the quantity of interest

# %% [markdown]
# **The Population**: 75 pandas, 25 otters, 50 buffalo, and 50 owls. 200 animals in total<br>
# **The Sample frame**: 24 animals in total<br>
# **The Sample**: 9 pandas, 3 otters, 6 buffalo, and 6 owls.<br>
# **The Type of Sample**: Stratified sample<br>
# **The Quantity of Interest**: Average food consumption over the next year/ future food costs

# %% [markdown]
# ### Problem 2
# ***
#
# A method to investigate the sensitivity of the sample mean and the sample median to extreme outliers is to replace one or more elements in a given dataset by a number $y$ and investigate the eﬀect when $y$ goes to inﬁnity. To illustrate this, consider the dataset
#
# $$
# 4.6 \quad
# 5.0 \quad
# 6.5 \quad
# 7.7 \quad
# 3.2 \quad
# 4.2 \quad
# 3.0 \quad
# 6.6
# $$
#
# **Part A**: Compute the sample mean and sample median.

# %%
def mean(A):
    summ = 0
    itt = 0
    for i in A:
        summ +=i
        itt+=1
    
    print ('Mean:',summ/itt)
a = np.array([4.6,5.0,6.5,7.7,3.2,4.2,3.0,6.6], dtype=float)
mean(a)

def median(A):
    Ap = np.sort(A)
    length = len(Ap)
    med = length/2 
    if length %2 == 0:
        med = int(med)
        ans =(Ap[med-1] + Ap[med])/2
    else:
        mid = int(med+.5)
        ans = Ap[mid]
    print ("Median:",ans)
median(a)
# Out:
# Mean: 5.1
# Median: 4.8

# %% [markdown]
# **Part B**: We replace the element $5.0$ by some real number $q$. What happens with the sample mean and the sample median of this new dataset as $q \rightarrow -\infty$?

# %%
# The mean will grow towards −∞ while the median will change from 4.8 to 4.4
def shortcut(A):
    mean(A)
    median(A)
b = np.array([4.6,-999999999999.0,6.5,7.7,3.2,4.2,3.0,6.6], dtype=float)
shortcut(b)
# Out:
# Mean: -124999999995.0
# Median: 4.4

# %% [markdown]
# **Part C**: We replace a number of elements by some real number $q$. How many elements do we need to replace so that the sample median of the new dataset goes to negative infinity as $q \rightarrow -\infty$?

# %% [markdown]
# In this case, the lowest 4 elements need to be replaced with q so that at least one end of the median (index 3) approaches −∞ and the other can stay at its initial value.

# %% [markdown]
# **Part D**: Suppose we have another data set of size $n$. How many elements do we need to replace by some real number $q$, so that the sample mean of the new dataset diverges as $q \rightarrow -\infty$? And how many elements do we need to replace, so that the sample median of the new dataset goes to infinity?

# %% [markdown]
# To allow the **mean** to to diverge to −∞, only one element needs to be replaced. To allow the **median** to go to −∞, n/2 elements need to be replaced

# %% [markdown]
# ### Problem 3
# ***
#
# Let $x_1, x_2, \ldots, x_n$ be $n$ observations of a variable of interest.  Recall that the sample mean $\bar{x}_n$ and sample variance $s^2_n$ are given by
#
# $$
# \bar{x}_n = \frac{1}{n}\sum_{k=1}^n x_k \quad \textrm{and} \quad s^2_n = \frac{1}{n-1}\sum_{k=1}^n \left( x_k - \bar{x}_n\right)^2
# $$
#
# where here the subscript $n$'s indicate the number of observations in the sample. Notice that a natural computation of the variance requires two passes over the data: one to compute the mean, and a second to subtract the mean from each observation and compute the sum of squares. It is often useful to be able to compute the variance in a single pass, inspecting each value $x_k$ only once; for example, when the data are being collected without enough storage to keep all the values, or when costs of memory access dominate those of computation. In this problem you will explore two methods for such an _online_ computation of the mean and variance.
#
# **Part A**: Show algebraically that the following relation holds between the mean of the first $n-1$ observations and the mean of all $n$ observations:
#
# $$
# \bar{x}_n = \bar{x}_{n-1} + \frac{x_n - \bar{x}_{n-1}}{n}
# $$

# %% [markdown]
# $$
# \frac{1}{n}\sum_{k=1}^n x_k \quad = \bar{x}_{n-1} + \frac{x_n - \bar{x}_{n-1}}{n}
# $$
# *
# $$
# \sum_{k=1}^n x_k \quad = {n}\bar{x}_{n-1} + x_n - \bar{x}_{n-1}
# $$
# *
# $$
# \sum_{k=1}^n x_k \quad = ({n}\bar{x}_{n-1} - \bar{x}_{n-1}) + x_n
# $$
# *
# $$
# \sum_{k=1}^n x_k \quad = \bar{x}_{n-1}({n-1}) + x_n
# $$
# *
# $$
# \sum_{k=1}^n x_k \quad = \frac{1}{n-1}\sum_{k=1}^{n-1} x_k({n-1}) + x_n
# $$
#
# $$
# \sum_{k=1}^n x_k \quad = \sum_{k=1}^{n-1} x_k + x_n
# $$

# %% [markdown]
# **Part B**: Write a function `my_sample_mean` that takes as its input a numpy array and returns the mean of that numpy array using the formulas from class (written above). You may *not* use numpy's built in mean function. Write another function `my_sample_var` that takes as its input a numpy array and returns the variance of that numpy array, again using the formulas from class (written above). You may *not* use any built-in sample variance functions.

# %%
def my_sample_mean(A):
    summ = 0
    itt = 0
    for i in A:
        summ +=i
        itt+=1
    
    print ('Mean:',summ/itt)
    return summ/itt

def my_sample_var(A):
    x_bar = my_sample_mean(A)
    summ = 0
    for i in range(0,len(A)):
        summ += (A[i] - x_bar)**2
        
#     summ/(len(A)-1)
    print('Variance:',(summ/(len(A)-1))**(1/2))

# %% [markdown]
# **Part C**: Use your functions from Part B to compute the sample mean and sample variance of the following array.
#
# `otter_weights = [25, 29, 40, 19, 7, 6, 3, 12, 19, 21, 22, 45, 27]`

# %%
otter_weights = [25, 29, 40, 19, 7, 6, 3, 12, 19, 21, 22, 45, 27]
my_sample_var(otter_weights)
# Out:
# Mean: 21.153846153846153
# Variance: 12.542236335984597

# %% [markdown]
# **Part D**: Implement a third function called `update_mean` that implements the formula whose valdity you proved in Part A. (Note: this function will need to take as its input three things: $x_n$, $\bar{x}_{n-1}$ and $n$.)
#
# Use this function to compute the values that you get from taking the mean of the first one otter, the first two otters, the first three otters, and so on up to all the otters. Store your otter means in a numpy array called `otterations`.
# $$
# \bar{x}_n = \bar{x}_{n-1} + \frac{x_n - \bar{x}_{n-1}}{n}
# $$

# %%
def update_mean(X, mean_1, n):
    return round(mean_1 + (X-mean_1)/n, 3)
otterations = []
meanInit = 0
for i in range(13):
    otterations.append(update_mean(otter_weights[i],meanInit, i+1))
    meanInit = update_mean(otter_weights[i],meanInit, i+1)
otterations
# Out:
# [25.0,
#  27.0,
#  31.333,
#  28.25,
#  24.0,
#  21.0,
#  18.429,
#  17.625,
#  17.778,
#  18.1,
#  18.455,
#  20.667,
#  21.154]

# %% [markdown]
# ### Problem 4
# ***
# Some claim that the final hours aboard the RMS Titanic were marked by class warfare; others claim it was characterized by male chivalry.  We have the data on survival rates by class and by sex, so let's figure out whether there is evidence for these scenarios. Access the titanic data in `titanic_data.csv` and store it in a Pandas DataFrame. The data contains information pertaining to class status (**Pclass**), survival of passengers (**Survived**), and gender (**Sex**), among others.

# %% [markdown]
# **Part A**: Consider the two claims: class warfare, and male chivalry. Suppose that class warfare occurred in the final hours aboard the Titanic.  What patterns might you expect to see in the data?  Suppose that male chivalry was widespread during the final hours insteas. What patterns might you then expect to see in the data?  Explain both of these hypothesized patterns in words. Are these two hypotheses mutually exclusive or not?

# %% [markdown]
# ** * **The first question of class warfare would show a priority of the higher class people would all be getting on the boats. This would most likely take priority with children then woman then men. What you would see by looking at the raw data would be that men in higher classes would be on boats before woman and children of a lower class. So if a single middle class passenger survived, then all Upper (higher) class passengers would survive.
#
# The second question of chivalry would show a pure priority towards woman and children. For the most part, no man would be getting on the boat. looking at the raw data, you would see that there is a piority to woman and children together. If a woman has a child, she can get off the boat, if a woman does not have a child, she is less likely to make it on the boat.
#
# These two hypotheses do not technically have to be mutually exclusive. While the rich may have gotten on the boat first, they may have also prioritized woman and children first.

# %% [markdown]
# **Part B**: Create a clean data set by removing any rows from the DataFrame that are missing values corresponding to **Survived**, **Pclass**, **Age**, or **Sex**. Store the clean data in a DataFrame called dfTitanic.

# %%
dfTitanic = pd.read_csv('titanic_data.csv')
dfTitanic = dfTitanic[dfTitanic.Survived.notnull()]
dfTitanic = dfTitanic[dfTitanic.Pclass != 0]
dfTitanic = dfTitanic[dfTitanic.Sex.notnull()]
dfTitanic = dfTitanic[dfTitanic.Age.notnull()]
dfTitanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  36.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  18.0      1
# 2                             Heikkinen, Miss. Laina  female  14.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  27.0      1
# 4                           Allen, Mr. William Henry    male  63.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Part C**: Determine the fraction of survivors from each passenger class.

# %%
dfUpper = dfTitanic.loc[dfTitanic["Pclass"]==1]
upper_passengers = len(dfUpper)
upper_survived = dfUpper["Survived"].sum()

dfMiddle = dfTitanic.loc[dfTitanic["Pclass"]==2]
middle_passengers = len(dfMiddle)
middle_survived = dfMiddle["Survived"].sum()

dfLower = dfTitanic.loc[dfTitanic["Pclass"]==3]
lower_passengers = len(dfLower)
lower_survived = dfLower["Survived"].sum()

dfUpper.head()

print (upper_survived,"/",upper_passengers, "(",upper_survived/upper_passengers,")")
print (middle_survived,"/",middle_passengers, "(",middle_survived/middle_passengers,")")
print (lower_survived,"/",lower_passengers, "(",lower_survived/lower_passengers,")")
# Out:
# 108 / 168 ( 0.6428571428571429 )
# 70 / 145 ( 0.4827586206896552 )
# 101 / 401 ( 0.2518703241895262 )

# %% [markdown]
# **Part D**: Compute the fraction of survivors according to class and gender.  Did men in first class or women in third class have a higher survival rate?

# %%
upper_menP = len(dfUpper.loc[dfTitanic["Sex"]=="male"])
upper_menS = dfUpper.loc[dfTitanic["Sex"]=="male", "Survived"].sum()

upper_womenP = len(dfUpper.loc[dfTitanic["Sex"]=="female"])
upper_womanS = dfUpper.loc[dfTitanic["Sex"]=="female", "Survived"].sum()

middle_menP = len(dfMiddle.loc[dfTitanic["Sex"]=="male"])
middle_menS = dfMiddle.loc[dfTitanic["Sex"]=="male", "Survived"].sum()

middle_womenP = len(dfMiddle.loc[dfTitanic["Sex"]=="female"])
middle_womenS = dfMiddle.loc[dfTitanic["Sex"]=="female", "Survived"].sum()

lower_menP = len(dfLower.loc[dfTitanic["Sex"]=="male"])
lower_menS = dfLower.loc[dfTitanic["Sex"]=="male", "Survived"].sum()

lower_womenP = len(dfLower.loc[dfTitanic["Sex"]=="female"])
lower_womenS = dfLower.loc[dfTitanic["Sex"]=="female", "Survived"].sum()

print("First Class Men Survival Rate:", upper_menS,"/",upper_menP, "(",upper_menS/upper_menP,")")
print("Third Class Woman Survial Rate:",lower_womenS,"/",lower_womenP, "(",lower_womenS/lower_womenP,")")
# Out:
# First Class Men Survival Rate: 36 / 93 ( 0.3870967741935484 )
# Third Class Woman Survial Rate: 62 / 118 ( 0.5254237288135594 )

# %% [markdown]
# ** * **It would appear that first class men had a lower survival rate than third class woman

# %% [markdown]
# **Part E**: How would you characterize the distribution of **AGE**? (By _characterize_ we mean that you should indicate whether the data are unimodal, bimodal, multimodal, symmetric, negatively skewed, positively skewed, etc.)  Make any necessary graphical summaries to justify your conclusion.

# %%
ageGraph = dfTitanic[["Age","Sex","Pclass","Survived"]]
ageGraph = ageGraph.sort_values(by="Age", ascending=True).reset_index(drop=True)
ageGraph["Age"].sort_values().plot(kind='bar',use_index=False)

# %% [markdown]
# It would appeat that the data for age has a unimodual characteristic around the mid twenties with a peak.(I dont really know how to use jupyter notebooks and ive never plotted anything using python)

# %% [markdown]
# **Part F**: Were the median and mean ages for females who survived higher or lower than for females who did not survive?

# %%
age_women = ageGraph.loc[ageGraph["Sex"]=="female"]
age_womenS = age_women.loc[age_women["Survived"]==1].reset_index(drop=True)
age_womenNS = age_women.loc[age_women["Survived"]==0].reset_index()

womenSLen = len(age_womenS)
womenSAgeTot = age_womenS["Age"].sum()

womenNSLen = len(age_womenNS)
womenNSAgeTot = age_womenNS["Age"].sum()

print("Mean age of women who survived:", womenSAgeTot/womenSLen)
print("Mean age of women who did not survived:", womenNSAgeTot/womenNSLen)

mid1 = womenSLen/2

mid2 = (womenNSLen+1)/2

print("Median age of women who survived:", (age_womenS.loc[mid1-1,"Age"]+age_womenS.loc[mid1,"Age"])/2)
print("Median age of women who did not survive:", age_womenNS.loc[mid2,"Age"])

#print("Median:",(ageGraph.loc[mid,"Age"]+ageGraph.loc[mid2,"Age"])/2 )
# Out:
# Mean age of women who survived: 28.40558510638298
# Mean age of women who did not survived: 28.922063492063494
# Median age of women who survived: 26.0
# Median age of women who did not survive: 29.0

# %% [markdown]
# The women who survived appear to have been slightly younger on overall. Their average and the median are both smaller than women who did not survive.

# %% [markdown]
# **Part G**: Do the data suggest class warfare, male chivalry, or some combination of both characteristics in the final hours aboard the Titanic?  Justify your conclusion based on the computations done above, or do any other analysis that you like, but be sure to clearly justify your conclusion.

# %% [markdown]
# ** * ** The Data seems to show that there is an initial bias of chivalry, then a bias of class, which some equal bias of age. Younger First class woman were one end of the spectrum, while older third class men were the other end. The young woman were much more likely to survive then the older men

# %% [markdown]
# ### Problem 5 - Not anotter homework problem! :(
# ***
#
# Otters are undisputedly one of nature's most awesome animals. From a cursory Google Image Search of *baby otter* or *otters holding hands* or *otters water slide* this is easy to demonstrate.
#
# Because the CS Department was able to pull a few strings, we have obtained a dataset of sea otter behavior. For each otter studied, the dataset contains:
#
# - **hhrecord**: the otter's personal record for hand-holding (hours; 999)
# - **pawsize**: the size of the otter's paw (unspecified units; 999)
# - **floatation**: boolean, indicating whether the otter displayed leadership in floatation. (9)
# - **satscore**: the otter's projected SAT score percentile. (unclear why this was included; 99)
# - **height**: otter's height (unspecified units; 99)
# - **weight**: otter's weight (unspecified units; 999)
# - **urchins**: boolean, indicating whether the otter was observed eating urchins (9)
#
# All these data are included in the whitespace-delimited file `otters.data`

# %% [markdown]
# **Part A**: Create a clean data set that removes subjects if any observations on the subject are unknown.  Note that that collectors of the data set used values like $9$, $99$, $999$, to denote unknown values. Those values are listed parenthetically in the description above Store the modified data set in a Pandas DataFrame called dfOtters.

# %%
dfOtters = pd.read_csv("otters.data", delim_whitespace=True)
dfOtters = dfOtters[dfOtters.hhrecord != 999]
dfOtters = dfOtters[dfOtters.pawsize != 999]
dfOtters = dfOtters[dfOtters.floatation != 9]
dfOtters = dfOtters[dfOtters.satscore != 99]
dfOtters = dfOtters[dfOtters.height != 99]
dfOtters = dfOtters[dfOtters.weight != 999]
dfOtters = dfOtters[dfOtters.urchins != 9]
dfOtters = dfOtters.sort_values(by="hhrecord", ascending=True)
dfOtters
# Out:
#       hhrecord  pawsize  floatation  satscore  height  weight  urchins
# 978         55      204           0        35      65     140        0
# 912         58      245           0        34      64     156        1
# 829         62      228           0        24      61     107        0
# 1139        63      236           1        24      58      99        0
# 1065        65      232           0        24      66     125        1
# 1035        65      237           0        31      67     130        0
# 462         68      223           0        32      66     149        1
# 500         69      232           0        31      59     103        1
# 1169        71      254           0        19      61     145        1
# 309         71      281           0        32      60     117        1
# 361         71      234           0        32      64     110        1
# 529         71      277           0        40      69     135        0
# ...

# %% [markdown]
# **Part B**: Use the information in dfOtters to create a density histogram of the hand-holding records of otters who do not eat sea urchins (urchins=0) and another histogram placed directly below the first in the same graphics device for the hand-holding records of otters who do eat urchins (urchins=1).  Make the range of the horizontal axis $30$ to $180$ (hours) for both histograms.  Make sure to give each subplot titles and label axes.

# %%
dfOttersLater = dfOtters[["hhrecord","urchins"]]
dfOttersHHnU = dfOtters.loc[dfOtters["urchins"]==0]
dfOttersHHnU = dfOttersHHnU[["hhrecord","urchins"]]
dfOttersHHU = dfOtters.loc[dfOtters["urchins"]==1]
dfOttersHHU = dfOttersHHU[["hhrecord","urchins"]]
dfOttersHHU.hist(normed = True,range=[30,180],column="hhrecord")
plt.suptitle('HH Record Otters eating Urchins')
dfOttersHHnU.hist(normed = True,range=[30,180],column="hhrecord")
plt.suptitle('HH Record Otters not eating Urchins')
# Out:
# Text(0.5,0.98,'HH Record Otters not eating Urchins')

# %% [markdown]
# **Part C**: Based on the histograms in **Part B**, characterize the distribution of hand-holding records for both urchin and non-urchin eaters.

# %% [markdown]
# Otters that **eat urchins** hold hands for an overall less amount of time. There is a larger cluster of hand holding in the range of around 90-137 hours.
# Otters that **dont eat urchins** seem to be holding hands for a longer period of time. Their concentration seems to be in the range of 105-135 hours, with a slightly smaller amount at the range 135-150(ish).
#
# Urchins make otters less adorable by making them not want to hold hands

# %% [markdown]
# **Part D**: What are the mean and median hand-holding record differences between otters who eat urchins and otters who don't?  Can you think of any reason not to use the mean as a measure of center to compare records for this problem?

# %%
dfOttersHHU = dfOttersHHU.reset_index(drop=True)
dfOttersHHnU =dfOttersHHnU.reset_index(drop=True)
ottersHHUMean = round(dfOttersHHU["hhrecord"].sum()/len(dfOttersHHU),3)
print(len(dfOttersHHU))
print("Urchins Mean:",ottersHHUMean)
if len(dfOttersHHU) % 2 == 0:
    mid1 = len(dfOttersHHU)
    ottersHHUMedian = (dfOttersHHU.loc[len(dfOttersHHU)/2,"hhrecord"] + dfOttersHHU[(len(dfOttersHHU)/2)+1,"hhrecord"])/2
else:
    ottersHHUMedian = dfOttersHHU.loc[(len(dfOttersHHU)+1)/2,"hhrecord"]
    
print("Urchins Median:", ottersHHUMedian)
print()
ottersHHnUMean = round(dfOttersHHnU["hhrecord"].sum()/len(dfOttersHHnU),3)

print(len(dfOttersHHnU))
print("No Urchins Mean:", ottersHHnUMean)
if len(dfOttersHHnU) % 2 == 0:
    mid1 = len(dfOttersHHnU)
    ottersHHnUMedian = (dfOttersHHnU.loc[len(dfOttersHHnU)/2,"hhrecord"] + dfOttersHHU[(len(dfOttersHHU)/2)+1,"hhrecord"])/2
else:
    ottersHHnUMedian = dfOttersHHnU.loc[358,"hhrecord"]
    
print("No Urchins Median:",ottersHHnUMedian)
# Out:
# 459
# Urchins Mean: 113.819
# Urchins Median: 115
#
# 715
# No Urchins Mean: 123.085
# No Urchins Median: 123

# %% [markdown]
# **Part E**: Create side-by-side box-and-whisker plots to compare the hand-holding records of otters who eat urchins and otters who do not.  Use the box-and-whisker plot conventions discussed in lecture.

# %%
test = dfOttersLater.boxplot(column='hhrecord', by="urchins")
# I dont know what this error means but still works
# Out:
# C:\Users\srede\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# **Part F**: Using the box-and-whisker plots from **Part E** comment on the distributions of hand-holding records of otters within each urchin / non-urchin groups as well as the comparison of the two classes.

# %% [markdown]
# For non-Urchin eating otters, there is a lot of outlying data, which seems to acutally be balanced because Q1 is fairly close to the middle of Q2 and Q3. Urhcin eating otters has less outlying data, which shows that potentially urchin eating otters tend to hold hands fo the same amout of time because of some form of community
# This view also helps show the mean difference between the two values along with the median values.

# %% [markdown]
# ### Problem 6: Cleaning Election Results Data
# ***
#
# The file 2014\_election\_results.csv contains data from congressional district races during the 2014 midterm elections.  The problem is that the data is **extremely dirty**.  Your goal in the problem will be to use Pandas to clean the election result data and then, if possible, determine the names of the winners in each congressional district as well as the vote percentage margin that they won by.  Remember that data cleaning and wrangling is a messy business.  Don't be afraid to roll your sleeves up and get hacky!
#
# **Part A**: Complete the clean_election_data( ) function to return a clean DataFrame that accomplishes the following:
#
# - remove rows in the DataFrame that are missing values in columns **STATE**, **D**, and/or **GENERAL PERCENT**
#
# <p> </p>
#
# - replace unknown names in **CANDIDATE NAME** with:
#     - the value from **CANDIDATE NAME (Last)**, if available
#     - the string "UNKNOWN" if impossible to determine the full or last name
#     - **Note**: besides "NaN", data collectors appear to have used the string "Scattered" to indicate missing names as well
# <p> </p>
# - convert the strings in **GENERAL PERCENT** to values of type float between $0$ and $100$
# <p> </p>
# - restrict the DataFrame to only the columns **STATE**, **D**, **CANDIDATE NAME**, **GENERAL PERCENT**

# %%
def clean_election_data():
    '''
    Function to clean election data 

    '''
    
    # read in dirty data 
    df = pd.read_csv("2014_election_results.csv") 
    columns = ['STATE','D','CANDIDATE NAME','GENERAL PERCENT']
    for i,row in df.iterrows():
        if pd.isnull(row['STATE']) or pd.isnull(row['D']) or pd.isnull(row['GENERAL PERCENT']):
            df = df.drop(i)
            
        if row['CANDIDATE NAME'] == 'Scattered' or pd.isnull(row['CANDIDATE NAME']):
            if pd.isnull(row['CANDIDATE NAME (Last)']) or row['CANDIDATE NAME (Last)'] == 'Scattered':
                row['CANDIDATE NAME'] = 'UNKNOWN'
            else:
                row['CANDIDATE NAME'] = row['CANDIDATE NAME (Last)']
        if pd.notnull(row['GENERAL PERCENT']):
            row['GENERAL PERCENT']= float(row['GENERAL PERCENT'].strip('%').replace(',', '.'))
    for extra in df.columns:
        if extra not in columns:
            del df[extra]
    return dfClean
dfClean = clean_election_data()
dfClean.head(40)
# Out:
#              STATE  D                  CANDIDATE NAME GENERAL PERCENT
# 0          Alabama  1                  Byrne, Bradley           68.16
# 1          Alabama  1              LeFlore, Burton R.           31.71
# 2          Alabama  1                         UNKNOWN            0.13
# 5          Alabama  2                    Roby, Martha          67,34%
# 6          Alabama  2                             NaN          32,56%
# 7          Alabama  2                       Scattered           0,09%
# 10         Alabama  3                    Rogers, Mike          66,12%
# 13         Alabama  3                 Smith, Jesse T.          33,72%
# 14         Alabama  3                       Scattered           0,16%
# 17         Alabama  4                Aderholt, Robert          98,57%
# 18         Alabama  4                       Scattered           1,43%
# 21         Alabama  5                      Brooks, Mo          74,42%
# ...

# %% [markdown]
# **Part B**: Complete the function winners_and_margins( ) that takes in your clean DataFrame from **Part A** and returns a DataFrame with one row per state-district pair and with columns **STATE**, **D**, **WINNER**, and **MARGIN** where
#
# - **STATE** and **D** are as defined in the original DataFrame
# <p> </p>
# - **WINNER** is the name of the candidate that had the largest general vote percentage (which may possibly be "UNKNOWN")
# <p> </p>
# - **MARGIN** is the difference between the winning general vote percentage and the second highest vote percentage.  If there is only one candidate in a particular district you should list the general vote percentage obtained by the sole candidate.
#
# <p> </p>
#
# Finally, your DataFrame should be **sorted from most contentious races to least contentious** (i.e. from smallest winning margin to the largest).

# %%
def winners_and_margins(df):
    dfWinners = pd.DataFrame(columns=['STATE','D','WINNER','MARGIN'])
    prevState = ''
    i = 0
    prevD = -1
    count = 0
    prevPerc = 0
    for i,row in df.iterrows():
        if row['STATE']!=prevState:
            prevState = row['STATE']
            count = 1
            prevD = row['D']
            prevPerc = row['GENERAL PERCENT']
            winner = row['CANDIDATE NAME']
        else:
            if prevD == row['D']:
                count+=1
                if count == 2:
                    margin = prevPerc - row['GENERAL PERCENT']
        
                    dfWinners.loc[i] = [prevState,prevD,winner,margin]
                    i=-1
            else:
                if count == 1:
                    dfWinners.loc[i] = ([prevState,prevD,winner,prevPerc])
                
                prevD = row['D']
                winner = row['CANDIDATE NAME']
                prevPerc = row['GENERAL PERCENT']    
                count = 1
    return dfWinners
winners_and_margins()
# Out:
#                STATE   D                         WINNER  MARGIN
# 1            Alabama   1                 Byrne, Bradley   36.45
# 6            Alabama   2                   Roby, Martha   34.78
# 13           Alabama   3                   Rogers, Mike   32.40
# 18           Alabama   4               Aderholt, Robert   97.14
# 24           Alabama   5                     Brooks, Mo   49.25
# 36           Alabama   6                   Palmer, Gary   52.48
# 44           Alabama   7               Sewell, Terri A.   96.74
# 55            Alaska   0                     Young, Don   10.00
# 67    American Samoa   0                   Amata, Aumua   11.22
# 80           Arizona   1               Kirkpatrick, Ann    5.22
# 89           Arizona   2                            NaN    0.07
# 96           Arizona   3                Grijalva, Raul    11.49
# 104          Arizona   4                            NaN   44.17
# 111          Arizona   5                            NaN   39.16
# ...
